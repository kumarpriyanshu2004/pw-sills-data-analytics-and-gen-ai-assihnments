# %% [markdown]
# '''
# 1. What is a random variable in probability theory?
# A random variable is a function that assigns numerical values to the outcomes of a random experiment. It provides a way to quantify uncertain outcomes.
#
# 2. What are the types of random variables?
# There are two main types:
#
# Discrete Random Variable: Takes specific, countable values (e.g., number of heads in 3 coin tosses).
#
# Continuous Random Variable: Takes values from an infinite range (e.g., height, time, temperature).
#
# 3. What is the difference between discrete and continuous distributions?
# Discrete Distribution: Deals with distinct, separate values (e.g., Binomial, Poisson).
#
# Continuous Distribution: Deals with any value within a range (e.g., Normal, Exponential).
#
# 4. What are probability distribution functions (PDF)?
# A PDF gives the probability density of a continuous random variable. For a discrete variable, the equivalent is the probability mass function (PMF).
# For a continuous variable, the probability that it lies in an interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b] is:
#
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# PDF describes the likelihood of a specific value or range.
#
# CDF gives the cumulative probability that a variable is less than or equal to a given value:
#
# 𝐹
# (
# 𝑥
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# F(x)=P(X≤x)
# 6. What is a discrete uniform distribution?
# A discrete uniform distribution assigns equal probability to each outcome in a finite set.
# Example: For a fair 6-sided die, each face has a probability of
# 1
# 6
# 6
# 1
# ​
#  .
#
# 7. What are the key properties of a Bernoulli distribution?
# Two outcomes: success (1) or failure (0)
#
# Probability of success:
# 𝑝
# p, failure:
# 1
# −
# 𝑝
# 1−p
#
# Mean:
# 𝑝
# p, Variance:
# 𝑝
# (
# 1
# −
# 𝑝
# )
# p(1−p)
#
# 8. What is the binomial distribution, and how is it used in probability?
# It represents the number of successes in
# 𝑛
# n independent Bernoulli trials:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# Used to model situations like passing/failing tests or success/failure in experiments.
#
# 9. What is the Poisson distribution and where is it applied?
# Models the number of events in a fixed interval when events occur independently and at a constant rate:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝑒
# −
# 𝜆
# 𝜆
# 𝑘
# 𝑘
# !
# P(X=k)=
# k!
# e
# −λ
#  λ
# k
#
# ​
#
# Applied in modeling call arrivals, decay events, etc.
#
# 10. What is a continuous uniform distribution?
# Probability is uniformly distributed over an interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b]:
#
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝑏
# −
# 𝑎
# ,
# for
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
# f(x)=
# b−a
# 1
# ​
#  ,for a≤x≤b
# 11. What are the characteristics of a normal distribution?
# Bell-shaped, symmetric curve
#
# Defined by mean (μ) and standard deviation (σ)
#
# Mean = Median = Mode
#
# 68-95-99.7 rule applies for σ intervals
#
# 12. What is the standard normal distribution, and why is it important?
# Normal distribution with
# 𝜇
# =
# 0
# μ=0 and
# 𝜎
# =
# 1
# σ=1
#
# Used to compute Z-scores, which help compare values from different normal distributions
#
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# The CLT states that, for a large enough sample size, the distribution of the sample mean approaches a normal distribution, regardless of the population's original distribution.
# It's foundational for statistical inference.
#
# 14. How does the Central Limit Theorem relate to the normal distribution?
# The CLT justifies the use of the normal distribution for sample means, making it possible to apply Z-tests and confidence intervals even for non-normal populations.
#
# 15. What is the application of Z statistics in hypothesis testing?
# Z-statistics measure how far a sample mean is from the population mean in standard deviations.
# Used in:
#
# Z-tests for means/proportions
#
# Confidence intervals
#
# Comparing sample vs. population parameters
#
# 16. How do you calculate a Z-score, and what does it represent?
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# It represents how many standard deviations a value
# 𝑋
# X is from the mean
# 𝜇
# μ.
#
# 17. What are point estimates and interval estimates in statistics?
# Point Estimate: A single value estimate (e.g., sample mean
# 𝑥
# ˉ
# x
# ˉ
#  )
#
# Interval Estimate: A range (confidence interval) likely to contain the true parameter
#
# 18. What is the significance of confidence intervals in statistical analysis?
# Confidence intervals provide a range of values that is likely to contain the true population parameter with a certain probability (e.g., 95%).
#
# 19. What is the relationship between a Z-score and a confidence interval?
# Z-scores are used to determine the margin of error in a confidence interval:
#
# CI
# =
# 𝑥
# ˉ
# ±
# 𝑍
# 𝛼
# /
# 2
# ⋅
# 𝜎
# 𝑛
# CI=
# x
# ˉ
#  ±Z
# α/2
# ​
#  ⋅
# n
# ​
#
# σ
# ​
#
# 20. How are Z-scores used to compare different distributions?
# By converting values from different distributions into a common standardized scale, Z-scores enable fair comparison, regardless of original scale or units.
#
# 21. What are the assumptions for applying the Central Limit Theorem?
# Sample size is large enough (usually
# 𝑛
# ≥
# 30
# n≥30)
#
# Observations are independent
#
# Population has finite variance
#
# 22. What is the concept of expected value in a probability distribution?
# The expected value is the theoretical average outcome of a random variable:
#
# Discrete:
# 𝐸
# [
# 𝑋
# ]
# =
# ∑
# 𝑥
# 𝑖
# 𝑃
# (
# 𝑥
# 𝑖
# )
# E[X]=∑x
# i
# ​
#  P(x
# i
# ​
#  )
#
# Continuous:
# 𝐸
# [
# 𝑋
# ]
# =
# ∫
# 𝑥
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# E[X]=∫xf(x)dx
#
# 23. How does a probability distribution relate to the expected outcome of a random variable?
# The probability distribution assigns likelihoods to outcomes, and the expected value summarizes the long-run average outcome based on these probabilities.
#
#
#
# ```
# # This is formatted as code
# ```
#
#
# '''
